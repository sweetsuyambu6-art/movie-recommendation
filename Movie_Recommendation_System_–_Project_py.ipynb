# %% [markdown]
# <a href="https://colab.research.google.com/github/sweetsuyambu6-art/movie-recommendation/blob/main/Movie_Recommendation_System_%E2%80%93_Project_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import streamlit as st
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load dataset
movies = pd.read_csv(r"/content/imdb_movies_2024.csv")
movies = movies[['Movie Name', 'Cleaned_Storyline',"Storyline"]]

# Train vectorizer
vectorizer = TfidfVectorizer(stop_words='english')
movie_vectors = vectorizer.fit_transform(movies['Cleaned_Storyline'])

st.title("Movie Recommendation System")

user_story = st.text_area("Enter a movie storyline")

if st.button("Recommend"):
    user_vector = vectorizer.transform([user_story])

    similarity = cosine_similarity(user_vector, movie_vectors)

    top_movies = np.argsort(similarity[0])[::-1][:5]

    st.subheader("Top 5 Recommended Movies")

    for index in top_movies:
        st.write("🎬", movies.iloc[index]['Movie Name'])
        st.write("📖", movies.iloc[index]['Storyline'])
# Out:
# 2026-07-14 21:18:23.728 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-14 21:18:24.192
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-07-14 21:18:24.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-14 21:18:24.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-14 21:18:24.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-14 21:18:24.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-14 21:18:24.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-14 21:18:24.210 Session state does not function when running a script without `streamlit run`
# 2026-07-14 21:18:24.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-14 21:18:24.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-14 21:18:24.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-14 21:18:24.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-14 21:18:24.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-14 21:18:24.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-14 21:18:24.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-14 21:18:24.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
